# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %%
from fastai.vision import *

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to create different labels.

# %%
folder = 'black'
file = 'urls_black.txt'

# %%
folder = 'teddys'
file = 'urls_teddys.txt'

# %%
folder = 'layup'
file = 'layup.txt'

# %%
folder = 'dunk'
file = 'dunk.txt'

# %% [markdown]
# You will need to run this cell once per each category.

# %%
path = Path('data/dunk_or_layup')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
dest
# Out:
# PosixPath('data/dunk_or_layup/layup')

# %%
path.ls()
# Out:
# [PosixPath('data/dunk_or_layup/dunk'),
#  PosixPath('data/dunk_or_layup/cleaned.csv'),
#  PosixPath('data/dunk_or_layup/layup'),
#  PosixPath('data/dunk_or_layup/models')]

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![uploaded file](images/download_images/upload.png)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download your images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename as well as the destination folder and this function will download and save all images that can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
classes = ['dunk','layup']

# %%
path
# Out:
# PosixPath('data/dunk_or_layup')

# %%
dest
# Out:
# PosixPath('data/dunk_or_layup/layup')

# %%
dest
# Out:
# PosixPath('data/dunk_or_layup/dunk')

# %%
dest
file
# Out:
# 'layup.txt'

# %%
download_images(dest/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:15<00:00]
#     </div>
# Error https://www.wfmynews2.com/img/resize/content.wfmynews2.com/photo/2016/03/02/Maverick%20Rowan_1456980599018_704492_ver1.0.jpg?mode=pad&bgcolor=000000&scale=both&width=750&height=422 HTTPSConnectionPool(host='www.wfmynews2.com', port=443): Read timed out. (read timeout=4)
# Error https://cdnuploads.aa.com.tr/uploads/Contents/2018/12/24/thumbs_b_c_234f1180b036af43c6abe76cb4773289.jpg?v=101252 HTTPSConnectionPool(host='cdnuploads.aa.com.tr', port=443): Read timed out. (read timeout=4)

# %%
# If you have problems download, try with `max_workers=0` to see exceptions:
download_images(dest/file, dest, max_pics=20, max_workers=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-48faff03d961> in <module>
#       1 # If you have problems download, try with `max_workers=0` to see exceptions:
# ----> 2 download_images(dest/file, dest, max_pics=20, max_workers=0)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# dunk
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='194' class='' max='194', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [194/194 00:02<00:00]
#     </div>
# Image data/dunk_or_layup/dunk/00000036.gif has 1 instead of 3 channels
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/PIL/Image.py:1021: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry " +
# Image data/dunk_or_layup/dunk/00000127.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/dunk/00000171.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/dunk/00000068.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/dunk/00000051.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/dunk/00000179.gif has 1 instead of 3 channels
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/PIL/Image.py:1021: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry " +
# cannot identify image file <_io.BufferedReader name='data/dunk_or_layup/dunk/00000050.png'>
# Image data/dunk_or_layup/dunk/00000022.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/dunk/00000109.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/dunk_or_layup/dunk/00000055.png'>
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/PIL/Image.py:1021: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry " +
# cannot identify image file <_io.BufferedReader name='data/dunk_or_layup/dunk/00000119.jpeg'>
# Image data/dunk_or_layup/dunk/00000099.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/dunk/00000118.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/dunk/00000095.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/dunk/00000142.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/dunk_or_layup/dunk/00000060.jpg'>
# Image data/dunk_or_layup/dunk/00000100.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/dunk_or_layup/dunk/00000176.png'>
# Image data/dunk_or_layup/dunk/00000001.gif has 1 instead of 3 channels
# layup
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='197' class='' max='197', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [197/197 00:01<00:00]
#     </div>
# Image data/dunk_or_layup/layup/00000039.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/layup/00000037.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/dunk_or_layup/layup/00000181.jpg'>
# cannot identify image file <_io.BufferedReader name='data/dunk_or_layup/layup/00000127.jpg'>
# cannot identify image file <_io.BufferedReader name='data/dunk_or_layup/layup/00000035.jpg'>
# Image data/dunk_or_layup/layup/00000112.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/layup/00000068.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/dunk_or_layup/layup/00000128.png'>
# cannot identify image file <_io.BufferedReader name='data/dunk_or_layup/layup/00000134.jpg'>
# Image data/dunk_or_layup/layup/00000064.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/layup/00000075.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/layup/00000059.gif has 1 instead of 3 channels
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/PIL/Image.py:1021: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry " +
# cannot identify image file <_io.BufferedReader name='data/dunk_or_layup/layup/00000097.jpeg'>
# cannot identify image file <_io.BufferedReader name='data/dunk_or_layup/layup/00000147.jpg'>
# cannot identify image file <_io.BufferedReader name='data/dunk_or_layup/layup/00000114.jpg'>
# Image data/dunk_or_layup/layup/00000021.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/dunk_or_layup/layup/00000171.jpg'>
# Image data/dunk_or_layup/layup/00000153.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/layup/00000182.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/layup/00000149.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/layup/00000194.jpg has 4 instead of 3 channels
# Image data/dunk_or_layup/layup/00000073.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/layup/00000195.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/dunk_or_layup/layup/00000108.jpg'>
# cannot identify image file <_io.BufferedReader name='data/dunk_or_layup/layup/00000197.jpg'>
# Image data/dunk_or_layup/layup/00000163.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/layup/00000083.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/dunk_or_layup/layup/00000049.jpg'>
# image file could not be identified because WEBP support not installed
# Image data/dunk_or_layup/layup/00000071.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/layup/00000048.gif has 1 instead of 3 channels
# Image data/dunk_or_layup/layup/00000193.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/dunk_or_layup/layup/00000113.jpg'>
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/PIL/Image.py:1021: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry " +

# %% [markdown]
# ## View data

# %%
path
# Out:
# PosixPath('data/dunk_or_layup')

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
??ImageDataBunch.from_csv

# %%
path = Path('data/dunk_or_layup')

# %%
#If you already cleaned your data, run this cell instead of the one before
np.random.seed(42)
data = ImageDataBunch.from_csv(path, valid_pct=0.2, csv_labels='cleaned.csv',
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.classes
# Out:
# ['dunk', 'layup']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['dunk', 'layup'], 2, 77, 19)

# %% [markdown]
# ## Train model

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 00:14 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.859811</th>
#     <th>0.735787</th>
#     <th>0.473684</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.916613</th>
#     <th>1.223605</th>
#     <th>0.473684</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.882928</th>
#     <th>1.191959</th>
#     <th>0.526316</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.832820</th>
#     <th>1.157554</th>
#     <th>0.526316</th>
#   </tr>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(10, max_lr=slice(1e-5,1e-2))
# Out:
# Total time: 00:26 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.030058</th>
#     <th>2.412562</th>
#     <th>0.526316</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.016008</th>
#     <th>2.302458</th>
#     <th>0.473684</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.012381</th>
#     <th>2.169378</th>
#     <th>0.421053</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.009871</th>
#     <th>2.193012</th>
#     <th>0.421053</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.007874</th>
#     <th>2.224291</th>
#     <th>0.421053</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.010617</th>
#     <th>2.554371</th>
#     <th>0.421053</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.009049</th>
#     <th>2.724486</th>
#     <th>0.421053</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.007918</th>
#     <th>2.797595</th>
#     <th>0.421053</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.006991</th>
#     <th>2.725073</th>
#     <th>0.421053</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.007318</th>
#     <th>2.646409</th>
#     <th>0.421053</th>
#   </tr>
# </table>

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(9, figsize=(15,15))

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `ImageCleaner` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.

# %%
from fastai.widgets import *

# %% [markdown]
# First we need to get the file paths from our top_losses. We can do this with `.from_toplosses`. We then feed the top losses indexes and corresponding dataset to `ImageCleaner`.
#
# Notice that the widget will not delete images directly from disk but it will create a new csv file `cleaned.csv` from where you can create a new ImageDataBunch with the corrected labels to continue training your model.

# %%
DatasetType.

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Train)

# %%
ImageCleaner(ds, idxs, path)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff…
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Next Batch' to delete flagged photos and keep the rest in that row. `ImageCleaner` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses.ImageCleaner(ds, idxs)`

# %% [markdown]
# You can also find duplicates in your dataset and delete them! To do this, you need to run `.from_similars` to get the potential duplicates' ids and then run `ImageCleaner` with `duplicates=True`. The API works in a similar way as with misclassified images: just choose the ones you want to delete and click 'Next Batch' until there are no more images left.

# %%
ds, idxs = DatasetFormatter().from_similars(learn, ds_type=DatasetType.Train)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2/2 00:08<00:00]
#     </div>
# Computing similarities...

# %%
1+1
# Out:
# 2

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff…
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# Remember to recreate your ImageDataBunch from your `cleaned.csv` to include the changes you made in your data!

# %% [markdown]
# ## Putting your model in production

# %% [markdown]
# First thing first, let's export the content of our `Learner` object for production:

# %%
data.classes
# Out:
# ['black', 'grizzly', 'teddys']

# %%
learn.export()

# %% [markdown]
# This will create a file named 'export.pkl' in the directory where we were working that contains everything we need to deploy our model (the model, the weights but also some metadata like the classes or the transforms/normalization used).

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'black'/'00000021.jpg')
img
# Out:
# Image (3, 335, 260)

# %% [markdown]
# We create our `Learner` in production enviromnent like this, jsut make sure that `path` contains the file 'export.pkl' from before.

# %%
dest
# Out:
# 'data/bears/teddys'

# %%
path='data/bears'

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category black

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)

# %% [markdown]
# ## Things that can go wrong

# %% [markdown]
# - Most of the time things will train fine with the defaults
# - There's not much you really need to tune (despite what you've heard!)
# - Most likely are
#   - Learning rate
#   - Number of epochs

# %% [markdown]
# ### Learning rate (LR) too high

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1, max_lr=0.5)
# Out:
# Total time: 00:34 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>8.264834</th>
#     <th>1011092.250000</th>
#     <th>0.546667</th>
#   </tr>
# </table>

# %% [markdown]
# ### Learning rate (LR) too low

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# Previously we had this result:
#
# ```
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.030236    0.179226    0.028369    (00:14)
# 2      0.561508    0.055464    0.014184    (00:13)
# 3      0.396103    0.053801    0.014184    (00:13)
# 4      0.316883    0.050197    0.021277    (00:15)
# ```

# %%
learn.fit_one_cycle(5, max_lr=1e-5)
# Out:
# Total time: 02:36 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.325716</th>
#     <th>1.332780</th>
#     <th>0.720000</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.335411</th>
#     <th>1.267924</th>
#     <th>0.666667</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>1.322536</th>
#     <th>1.222382</th>
#     <th>0.680000</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>1.301710</th>
#     <th>1.194147</th>
#     <th>0.640000</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>1.310512</th>
#     <th>1.181008</th>
#     <th>0.640000</th>
#   </tr>
# </table>

# %%
learn.recorder.plot_losses()

# %% [markdown]
# As well as taking a really long time, it's getting too many looks at each image, so may overfit.

# %% [markdown]
# ### Too few epochs

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:14
# epoch  train_loss  valid_loss  error_rate
# 1      0.602823    0.119616    0.049645    (00:14)

# %% [markdown]
# ### Too many epochs

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
        ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
                              ),size=224, num_workers=4).normalize(imagenet_stats)

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
learn.unfreeze()

# %%
learn.fit_one_cycle(40, slice(1e-6,1e-4))
# Out:
# Total time: 06:39
# epoch  train_loss  valid_loss  error_rate
# 1      1.513021    1.041628    0.507326    (00:13)
# 2      1.290093    0.994758    0.443223    (00:09)
# 3      1.185764    0.936145    0.410256    (00:09)
# 4      1.117229    0.838402    0.322344    (00:09)
# 5      1.022635    0.734872    0.252747    (00:09)
# 6      0.951374    0.627288    0.192308    (00:10)
# 7      0.916111    0.558621    0.184982    (00:09)
# 8      0.839068    0.503755    0.177656    (00:09)
# 9      0.749610    0.433475    0.144689    (00:09)
# 10     0.678583    0.367560    0.124542    (00:09)
# 11     0.615280    0.327029    0.100733    (00:10)
# 12     0.558776    0.298989    0.095238    (00:09)
# 13     0.518109    0.266998    0.084249    (00:09)
# 14     0.476290    0.257858    0.084249    (00:09)
# 15     0.436865    0.227299    0.067766    (00:09)
# 16     0.457189    0.236593    0.078755    (00:10)
# 17     0.420905    0.240185    0.080586    (00:10)
# 18     0.395686    0.255465    0.082418    (00:09)
# 19     0.373232    0.263469    0.080586    (00:09)
# 20     0.348988    0.258300    0.080586    (00:10)
# 21     0.324616    0.261346    0.080586    (00:09)
# 22     0.311310    0.236431    0.071429    (00:09)
# 23     0.328342    0.245841    0.069597    (00:10)
# 24     0.306411    0.235111    0.064103    (00:10)
# 25     0.289134    0.227465    0.069597    (00:09)
# 26     0.284814    0.226022    0.064103    (00:09)
# 27     0.268398    0.222791    0.067766    (00:09)
# 28     0.255431    0.227751    0.073260    (00:10)
# 29     0.240742    0.235949    0.071429    (00:09)
# 30     0.227140    0.225221    0.075092    (00:09)
# 31     0.213877    0.214789    0.069597    (00:09)
# 32     0.201631    0.209382    0.062271    (00:10)
# 33     0.189988    0.210684    0.065934    (00:09)
# 34     0.181293    0.214666    0.073260    (00:09)
# 35     0.184095    0.222575    0.073260    (00:09)
# 36     0.194615    0.229198    0.076923    (00:10)
# 37     0.186165    0.218206    0.075092    (00:09)
# 38     0.176623    0.207198    0.062271    (00:10)
# 39     0.166854    0.207256    0.065934    (00:10)
# 40     0.162692    0.206044    0.062271    (00:09)
